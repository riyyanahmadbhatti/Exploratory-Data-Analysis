# %%
import pandas as pd
#making dataframes of the 5 years excel sheet
df2015=pd.read_csv("2015.csv")
df2016=pd.read_csv("2016.csv")
df2017=pd.read_csv("2017.csv")
df2018=pd.read_csv("2018.csv")
df2019=pd.read_csv("2019.csv")
#displaying one of the dataframe 
df2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
for x, val in enumerate(df2015["Health (Life Expectancy)"]):
    if val>=0.5 and val<=1.0:#finding the country with life expectancy between 0.5 and 1
        print(df2015["Country"][x])
# Out:
# Switzerland
# Iceland
# Denmark
# Norway
# Canada
# Finland
# Netherlands
# Sweden
# New Zealand
# Australia
# Israel
# Costa Rica
# Austria
# Mexico
# United States
# Brazil
# Luxembourg
# Ireland
# Belgium
# United Arab Emirates
# United Kingdom
# Oman
# Venezuela
# Panama
# Germany
# Chile
# Qatar
# France
# Argentina
# Czech Republic
# Uruguay
# Colombia
# Thailand
# Saudi Arabia
# Spain
# Malta
# Taiwan
# Kuwait
# Suriname
# Trinidad and Tobago
# El Salvador
# Guatemala
# Uzbekistan
# Slovakia
# Japan
# South Korea
# Ecuador
# Bahrain
# Italy
# Bolivia
# Moldova
# Paraguay
# Kazakhstan
# Slovenia
# Lithuania
# Nicaragua
# Peru
# Belarus
# Poland
# Malaysia
# Croatia
# Libya
# Russia
# Jamaica
# North Cyprus
# Cyprus
# Algeria
# Kosovo
# Turkmenistan
# Mauritius
# Estonia
# Indonesia
# Vietnam
# Turkey
# Kyrgyzstan
# Bhutan
# Azerbaijan
# Pakistan
# Jordan
# Montenegro
# China
# Romania
# Serbia
# Portugal
# Latvia
# Philippines
# Morocco
# Macedonia
# Albania
# ...

# %%
count=0
for x, val in enumerate(df2016["Happiness Score"]):
    if count==10:#printing the first 10 countries with the highest happiness score
        break;
    print(df2015["Country"][x])
    count=count+1
# Out:
# Switzerland
# Iceland
# Denmark
# Norway
# Canada
# Finland
# Netherlands
# Sweden
# New Zealand
# Australia

# %%
#variables for total sum of values present for a single region
total1=0
total2=0
total3=0
total4=0
total5=0
total6=0
total7=0
total8=0
#variables to count the number of countries in specific region
count1=0
count2=0
count3=0
count4=0
count5=0
count6=0
count7=0
count8=0
#calculating the total sum of values and total countries in each region 
for x, val in enumerate(df2016["Region"]):
    if val=="Western Europe":
        total1=total1+df2015["Happiness Score"][x]
        count1=count1+1
    elif val=="North America":
        total2=total2+df2015["Happiness Score"][x]
        count2=count2+1
    elif val=="Australia and New Zealand":
        total3=total3+df2015["Happiness Score"][x]
        count3=count3+1
    elif val=="Middle East and Northern Africa":
        total4=total4+df2015["Happiness Score"][x]
        count4=count4+1
    elif val=="Latin America and Caribbean":
        total5=total5+df2015["Happiness Score"][x]
        count5=count5+1
    elif val=="Southeastern Asia":
        total6=total6+df2015["Happiness Score"][x]
        count6=count6+1
    elif val=="Sub-Saharan Africa":
        total7=total7+df2015["Happiness Score"][x]
        count7=count7+1
    elif val=="Central and Eastern Europe":
        total8=total8+df2015["Happiness Score"][x]
        count8=count8+1
#calculating and displaying the mean of each region
print("Mean happiness by Region")
print("Western Europe")
print(total1/count1)
print("North America")
print(total2/count2)
print("Australia and New Zealand")
print(total3/count3)
print("Middle East and Northeren Africa")
print(total4/count4)
print("Latin America and Caribbean")
print(total5/count5)
print("Southeasteren Asia")
print(total6/count6)
print("Sub-Saharan Africa")
print(total7/count7)
print("Central and Eastern Europe")
print(total8/count8)
# Out:
# Mean happiness by Region
# Western Europe
# 6.694619047619049
# North America
# 7.303
# Australia and New Zealand
# 7.324999999999999
# Middle East and Northeren Africa
# 5.357210526315789
# Latin America and Caribbean
# 6.101875000000001
# Southeasteren Asia
# 5.337666666666667
# Sub-Saharan Africa
# 4.19778947368421
# Central and Eastern Europe
# 5.35196551724138

# %%
print("Outlier in 2015")
print(" ")
#calculating outliers in a single year in evry column
col=df2015["Happiness Score"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
#calculating the quartiles 
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
#calculating the limits for the range 
for x, val in enumerate(df2015["Happiness Score"]):
    if val<=y1 or val>=y2:#displaying the countries that aren't in range 
        print(df2015["Country"][x])

col=df2015["Standard Error"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Standard Error"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Economy (GDP per Capita)"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Economy (GDP per Capita)"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Family"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Family"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Health (Life Expectancy)"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Health (Life Expectancy)"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Freedom"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Freedom"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Trust (Government Corruption)"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Trust (Government Corruption)"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Generosity"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Generosity"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

col=df2015["Dystopia Residual"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2015["Dystopia Residual"]):
    if val<=y1 or val>=y2:
        print(df2015["Country"][x])

print(" ")     
print("Outlier in 2016")
print(" ")

col=df2016["Happiness Score"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Happiness Score"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Lower Confidence Interval"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Lower Confidence Interval"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Lower Confidence Interval"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Lower Confidence Interval"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])        
        
col=df2016["Economy (GDP per Capita)"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Economy (GDP per Capita)"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Family"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Family"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Health (Life Expectancy)"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Health (Life Expectancy)"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Freedom"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Freedom"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])
        
col=df2016["Trust (Government Corruption)"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Trust (Government Corruption)"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Generosity"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Generosity"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])

col=df2016["Dystopia Residual"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2016["Dystopia Residual"]):
    if val<=y1 or val>=y2:
        print(df2016["Country"][x])
        
print(" ")     
print("Outlier in 2017")
print(" ")

col=df2017["Happiness.Score"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Happiness.Score"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Whisker.high"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Whisker.high"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Whisker.low"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Whisker.low"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])        
        
col=df2017["Economy..GDP.per.Capita."]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Economy..GDP.per.Capita."]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Family"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Family"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Health..Life.Expectancy."]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Health..Life.Expectancy."]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Freedom"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Freedom"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])
        
col=df2017["Trust..Government.Corruption."]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Trust..Government.Corruption."]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Generosity"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Generosity"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])

col=df2017["Dystopia.Residual"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2017["Dystopia.Residual"]):
    if val<=y1 or val>=y2:
        print(df2017["Country"][x])
        
print(" ")
print("Outlier in 2019")
print(" ")

col=df2018["Score"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018["Score"]):
    if val<=y1 or val>=y2:
        print(df2018["Country or region"][x])

col=df2018['Social support']
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018['Social support']):
    if val<=y1 or val>=y2:
        print(df2018['Country or region'][x])       
        
col=df2018["GDP per capita"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018["GDP per capita"]):
    if val<=y1 or val>=y2:
        print(df2018["Country or region"][x])


col=df2018["Healthy life expectancy"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018["Healthy life expectancy"]):
    if val<=y1 or val>=y2:
        print(df2018["Country or region"][x])

col=df2018["Freedom to make life choices"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018["Freedom to make life choices"]):
    if val<=y1 or val>=y2:
        print(df2018["Country or region"][x])
        
col=df2018["Perceptions of corruption"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018["Perceptions of corruption"]):
    if val<=y1 or val>=y2:
        print(df2018["Country or region"][x])

col=df2018["Generosity"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2018["Generosity"]):
    if val<=y1 or val>=y2:
        print(df2018["Country or region"][x])
        
        
print(" ")
print("Outlier in 2019")
print(" ")

col=df2019["Score"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019["Score"]):
    if val<=y1 or val>=y2:
        print(df2019["Country or region"][x])

col=df2019['Social support']
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019['Social support']):
    if val<=y1 or val>=y2:
        print(df2019['Country or region'][x])       
        
col=df2019["GDP per capita"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019["GDP per capita"]):
    if val<=y1 or val>=y2:
        print(df2019["Country or region"][x])


col=df2019["Healthy life expectancy"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019["Healthy life expectancy"]):
    if val<=y1 or val>=y2:
        print(df2019["Country or region"][x])

col=df2019["Freedom to make life choices"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019["Freedom to make life choices"]):
    if val<=y1 or val>=y2:
        print(df2019["Country or region"][x])
        
col=df2019["Perceptions of corruption"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019["Perceptions of corruption"]):
    if val<=y1 or val>=y2:
        print(df2019["Country or region"][x])

col=df2019["Generosity"]
q1=col.quantile(0.25)
q3=col.quantile(0.75)
iqr=q3-q1
x=iqr*1.5
y1=q1-x
y2=q3+x
for x, val in enumerate(df2019["Generosity"]):
    if val<=y1 or val>=y2:
        print(df2019["Country or region"][x])
# Out:
# Outlier in 2015
#
# Suriname
# Trinidad and Tobago
# Libya
# Jamaica
# Mozambique
# Lesotho
# Swaziland
# Liberia
# Djibouti
# Burundi
# Central African Republic
# Afghanistan
# Togo
# Switzerland
# Denmark
# Norway
# Finland
# Sweden
# New Zealand
# Luxembourg
# United Arab Emirates
# Singapore
# Qatar
# Hong Kong
# Somaliland region
# Georgia
# Rwanda
# Thailand
# Myanmar
# Mexico
# Hong Kong
# Sri Lanka
# Rwanda
# Syria
#
# Outlier in 2016
#
# Togo
# Denmark
# Switzerland
# Norway
# Finland
# New Zealand
# Sweden
# Luxembourg
# Singapore
# United Arab Emirates
# Qatar
# Somaliland Region
# Rwanda
# Malta
# Thailand
# Indonesia
# Myanmar
# Hong Kong
# Somalia
# Sri Lanka
# Botswana
# Rwanda
# Syria
#
# Outlier in 2017
#
# Benin
# Togo
# Syria
# Central African Republic
# Norway
# Denmark
# Switzerland
# Finland
# New Zealand
# Sweden
# Australia
# Ireland
# Luxembourg
# United Arab Emirates
# Singapore
# Qatar
# Rwanda
# Indonesia
# Myanmar
# Hong Kong S.A.R., China
# Somalia
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
x=df2015['Happiness Score']
y=df2015['Economy (GDP per Capita)']
#assigning x and y their respactive columns
plt.plot(x,y,'o',color='yellow');
#plotting the graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\__init__.py:879, in _rc_params_in_file(fname, transform, fail_on_error)
#     878 rc_temp = {}
# --> 879 with _open_file_or_url(fname) as fd:
#     880     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# ...

# %%
newdf=pd.DataFrame()
#making a new dataframe
newdf['Country']=df2015['Country']
newdf['Region']=df2015['Region']
newdf['2015']=df2015['Happiness Score']
newdf['2016']=df2016['Happiness Score']
newdf['2017']=df2017['Happiness.Score']
newdf['2018']=df2018['Score']
newdf['2019']=df2019['Score']
#assigning columns to the newdataframe using the rest of the excel sheets
newdf

# %%
#assigning labels to each of the graph
s1 = 'Switzerland 2015'
s2 = 'Switzerland 2016'
s3 = 'Switzerland 2017'
s4 = 'Switzerland 2018'
s5 = 'Switzerland 2019'
i1 = 'Iceland 2015'
i2 = 'Iceland 2016'
i3 = 'Iceland 2017'
i4 = 'Iceland 2018'
i5 = 'Iceland 2019'
#assigning variables of the values of the two countries every year
ss1=newdf['2015'][0]
ss2=newdf['2016'][0]
ss3=newdf['2017'][0]
ss4=newdf['2018'][0]
ss5=newdf['2019'][0]
ii1=newdf['2015'][1]
ii2=newdf['2016'][1]
ii3=newdf['2017'][1]
ii4=newdf['2018'][1]
ii5=newdf['2019'][1]
x = [0, 1]
#plotting the graph
plt.plot(x, [0,ss1], '-b', label=s1)  
plt.plot(x, [0,ii1], '-g', label=i1)  
plt.plot(x, [0,ss2], '-r', label=s2)  
plt.plot(x, [0,ii2], '-s', label=i2)  
plt.plot(x, [0,ss3], '-w', label=s3)  
plt.plot(x, [0,ii3], '-m', label=i3)  
plt.plot(x, [0,ss4], '-v', label=s4)  
plt.plot(x, [0,ii4], '-y', label=i4)  
plt.plot(x, [0,ss5], '-p', label=s5)  
plt.plot(x, [0,ii5], '-g', label=i5)  
plt.legend()

# %%
for x, val in enumerate(df2015["Economy (GDP per Capita)"]):
    if val<0.5:#displaying the countries with GDP lower than 0.5
        print(df2015["Country"][x])

# %%
#getting the highest correlation between two columns in a single year
highest_corr = 0.0
col_1, col_2 = None, None
tempdf = df2015.drop(columns=['Happiness Rank'])
totalcol = tempdf.select_dtypes(include=['float64']).columns
i = 0
j = 1
#traversing through the excel sheet and calculating the cols with most correlation with each other 
while i < len(totalcol):
    while j < len(totalcol):
        column1 = totalcol[i]
        column2 = totalcol[j]
        correlation = tempdf[column1].corr(tempdf[column2])
        if abs(correlation) > highest_corr:
            highest_corr = abs(correlation)
            col_1, col_2 = column1, column2
        
        j += 1
    i += 1
    j = i + 1
print("The highest correlation in 2015, is:" + str(highest_corr) )
print("Between columns: " + str(col_1) + " and " + str(col_2))
#same thing done for 2016 just changing the excel sheet
tempdf = df2016.drop(columns=['Happiness Rank'])
totalcol = tempdf.select_dtypes(include=['float64']).columns
i = 0
j = 1
while i < len(totalcol):
    while j < len(totalcol):
        column1 = totalcol[i]
        column2 = totalcol[j]
        correlation = tempdf[column1].corr(tempdf[column2])
        if abs(correlation) > highest_corr:
            highest_corr = abs(correlation)
            col_1, col_2 = column1, column2
        
        j += 1
    i += 1
    j = i + 1
print("The highest correlation in 2016, is:" + str(highest_corr) )
print("Between columns: " + str(col_1) + " and " + str(col_2))
